# %% [markdown]
# ## Week 2 Day 1
#
# And now! Our first look at OpenAI Agents SDK
#
# You won't believe how lightweight this is..

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">The OpenAI Agents SDK Docs</h2>
#             <span style="color:#00bfff;">The documentation on OpenAI Agents SDK is really clear and simple: <a href="https://openai.github.io/openai-agents-python/">https://openai.github.io/openai-agents-python/</a> and it's well worth a look.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# The imports

from dotenv import load_dotenv
from google import genai
from google.genai import types

# %%
# The usual starting point

load_dotenv(override=True)
client = genai.Client()
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %%
# Make an agent with name, instructions, model

chat = client.chats.create(
    model="gemini-3.5-flash",
    config=types.GenerateContentConfig(
        system_instruction="You are a helpful financial assistant.",
        tools=[], # Drop your Python functions straight in here
    )
)

# %%
# Run the joke with Runner.run(agent, prompt) then print final_output

response = chat.send_message("Hey, can you check the current price of GOOG for me?")

print(response.text)
# Out:
# I cannot provide the real-time price of GOOG (Alphabet Inc.) as I don't have access to live financial market data.
#
# To get the most accurate and up-to-the-minute price, you can check:
# *   **Google Finance** (just search "GOOG stock" on Google)
# *   **Yahoo Finance** (search ticker: GOOG)
# *   Your preferred stock tracking app or brokerage account.

# %% [markdown]
# ## Now go and look at the trace
#
# https://platform.openai.com/traces
